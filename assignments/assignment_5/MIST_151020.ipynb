# %%
import read_mist_models
import numpy as np
import matplotlib.pyplot as plt

# %%
eep1 = read_mist_models.EEP('MIST_v1.2_feh_p0.00_afe_p0.0_vvcrit0.0_EEPS/00100M.track.eep')
eep5 = read_mist_models.EEP('MIST_v1.2_feh_p0.00_afe_p0.0_vvcrit0.0_EEPS/00500M.track.eep')
eep10 = read_mist_models.EEP('MIST_v1.2_feh_p0.00_afe_p0.0_vvcrit0.0_EEPS/01000M.track.eep')
eep20 = read_mist_models.EEP('MIST_v1.2_feh_p0.00_afe_p0.0_vvcrit0.0_EEPS/02000M.track.eep')
# Out:
# Reading in: MIST_v1.2_feh_p0.00_afe_p0.0_vvcrit0.0_EEPS/00100M.track.eep
# Reading in: MIST_v1.2_feh_p0.00_afe_p0.0_vvcrit0.0_EEPS/00500M.track.eep
# Reading in: MIST_v1.2_feh_p0.00_afe_p0.0_vvcrit0.0_EEPS/01000M.track.eep
# Reading in: MIST_v1.2_feh_p0.00_afe_p0.0_vvcrit0.0_EEPS/02000M.track.eep

# %%
eep1.plot_HR()

# %%
plt.plot(eep1.eeps['log_Teff'], eep1.eeps['log_L'], label=r'$M=1\,\rm{M_{\odot}}$')
plt.xlim(5.5, 3.25)
plt.xlabel(r'log(T$_{\rm{eff}}$/K)')
plt.ylabel(r'log(L/L$_{\odot}$)')
plt.legend()
plt.tight_layout()

# %%
plt.plot(eep1.eeps['log_Teff'], eep1.eeps['log_L'], label=r'$M=1\,\rm{M_{\odot}}$')
plt.xlim(4.0, 3.4)
plt.xlabel(r'log(T$_{\rm{eff}}$/K)')
plt.ylabel(r'log(L/L$_{\odot}$)')
plt.legend()
plt.tight_layout()

# %%
plt.plot(eep5.eeps['log_Teff'], eep5.eeps['log_L'], label=r'$M=5\,\rm{M_{\odot}}$')
plt.xlim(6.0, 3.25)
plt.xlabel(r'log(T$_{\rm{eff}}$/K)')
plt.ylabel(r'log(L/L$_{\odot}$)')
plt.legend()
plt.tight_layout()

# %%
plt.plot(eep10.eeps['log_Teff'], eep10.eeps['log_L'], label=r'$M=10\,\rm{M_{\odot}}$')
plt.xlim(4.5, 3.25)
plt.xlabel(r'log(T$_{\rm{eff}}$/K)')
plt.ylabel(r'log(L/L$_{\odot}$)')
plt.legend()
plt.tight_layout()

# %%
plt.plot(eep20.eeps['log_Teff'], eep20.eeps['log_L'], label=r'$M=20\,\rm{M_{\odot}}$')
plt.xlim(4.75, 3.25)
plt.xlabel(r'log(T$_{\rm{eff}}$/K)')
plt.ylabel(r'log(L/L$_{\odot}$)')
plt.legend()
plt.tight_layout()

# %%
plt.plot(eep1.eeps['log_Teff'], eep1.eeps['log_L'], label=r'$M=1\,\rm{M_{\odot}}$')
plt.plot(eep5.eeps['log_Teff'], eep5.eeps['log_L'], label=r'$M=5\,\rm{M_{\odot}}$')
plt.plot(eep10.eeps['log_Teff'], eep10.eeps['log_L'], label=r'$M=10\,\rm{M_{\odot}}$')
plt.plot(eep20.eeps['log_Teff'], eep20.eeps['log_L'], label=r'$M=20\,\rm{M_{\odot}}$')
plt.xlim(6.0, 3.25)
plt.xlabel(r'log(T$_{\rm{eff}}$/K)')
plt.ylabel(r'log(L/L$_{\odot}$)')
plt.legend()
plt.tight_layout()

# %%
eep20.plot_HR(phases=[-1,0,2,3,4,6,7], phasecolor=['brown','black', 'red', 'blue',
                                                'orange', 'green', 'purple'],)
